# %%
#import libraries
import os
import requests
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
#import  environment variable
import alpha_vantage as av
av_api_key = os.getenv("ALPHA_VANTAGE_API_KEY")

# %%
def get_income_chart():

    base_url = 'https://www.alphavantage.co/query?'
    function = 'INCOME_STATEMENT'
    symbol = input("Enter the ticker symbol to retrieve the waterfall income chart for the last 5 years: ").upper()

    response = requests.get(f'{base_url}function={function}&symbol={symbol}&apikey={av_api_key}') 
    overview = response.json()

    annual_overview = overview['annualReports']
    df = pd.DataFrame(annual_overview)
    df_income_statement = df.replace({'None': 0})

    rev_0 = float(df_income_statement[['fiscalDateEnding', 'totalRevenue']].iloc[0][1])
    cogs_0 = float(df_income_statement[['fiscalDateEnding', 'costOfRevenue']].iloc[0][1]) * -1
    gross_prof_0 = float(df_income_statement[['fiscalDateEnding', 'grossProfit']].iloc[0][1])
    rd_0 = float(df_income_statement[['fiscalDateEnding', 'researchAndDevelopment']].iloc[0][1]) * -1
    ga_0 = float(df_income_statement[['fiscalDateEnding', 'sellingGeneralAdministrative']].iloc[0][1]) * -1
    opex_0 = float(df_income_statement[['fiscalDateEnding', 'totalOperatingExpense']].iloc[0][1]) * -1
    ebit_0 = float(df_income_statement[['fiscalDateEnding', 'operatingIncome']].iloc[0][1]) 
    other_inc_0 = float(df_income_statement[['fiscalDateEnding', 'otherNonOperatingIncome']].iloc[0][1]) 
    ebt_0 = float(df_income_statement[['fiscalDateEnding', 'incomeBeforeTax']].iloc[0][1]) 
    inc_tax_0 = float(df_income_statement[['fiscalDateEnding', 'taxProvision']].iloc[0][1]) * -1
    net_inc_0 = float(df_income_statement[['fiscalDateEnding', 'netIncome']].iloc[0][1])  

    rev_1 = float(df_income_statement[['fiscalDateEnding', 'totalRevenue']].iloc[1][1])
    cogs_1 = float(df_income_statement[['fiscalDateEnding', 'costOfRevenue']].iloc[1][1]) * -1
    gross_prof_1 = float(df_income_statement[['fiscalDateEnding', 'grossProfit']].iloc[1][1])
    rd_1 = float(df_income_statement[['fiscalDateEnding', 'researchAndDevelopment']].iloc[1][1]) * -1
    ga_1 = float(df_income_statement[['fiscalDateEnding', 'sellingGeneralAdministrative']].iloc[0][1]) * -1
    opex_1 = float(df_income_statement[['fiscalDateEnding', 'totalOperatingExpense']].iloc[1][1]) * -1
    ebit_1 = float(df_income_statement[['fiscalDateEnding', 'operatingIncome']].iloc[1][1]) 
    other_inc_1 = float(df_income_statement[['fiscalDateEnding', 'otherNonOperatingIncome']].iloc[1][1]) 
    ebt_1 = float(df_income_statement[['fiscalDateEnding', 'incomeBeforeTax']].iloc[1][1]) 
    inc_tax_1 = float(df_income_statement[['fiscalDateEnding', 'taxProvision']].iloc[1][1]) * -1
    net_inc_1 = float(df_income_statement[['fiscalDateEnding', 'netIncome']].iloc[1][1])  

    rev_2 = float(df_income_statement[['fiscalDateEnding', 'totalRevenue']].iloc[2][1])
    cogs_2 = float(df_income_statement[['fiscalDateEnding', 'costOfRevenue']].iloc[2][1]) * -1
    gross_prof_2 = float(df_income_statement[['fiscalDateEnding', 'grossProfit']].iloc[2][1])
    rd_2 = float(df_income_statement[['fiscalDateEnding', 'researchAndDevelopment']].iloc[2][1]) * -1
    ga_2 = float(df_income_statement[['fiscalDateEnding', 'sellingGeneralAdministrative']].iloc[2][1]) * -1
    opex_2 = float(df_income_statement[['fiscalDateEnding', 'totalOperatingExpense']].iloc[2][1]) * -1
    ebit_2 = float(df_income_statement[['fiscalDateEnding', 'operatingIncome']].iloc[2][1]) 
    other_inc_2 = float(df_income_statement[['fiscalDateEnding', 'otherNonOperatingIncome']].iloc[2][1]) 
    ebt_2 = float(df_income_statement[['fiscalDateEnding', 'incomeBeforeTax']].iloc[2][1]) 
    inc_tax_2 = float(df_income_statement[['fiscalDateEnding', 'taxProvision']].iloc[2][1]) * -1
    net_inc_2 = float(df_income_statement[['fiscalDateEnding', 'netIncome']].iloc[2][1])  

    rev_3 = float(df_income_statement[['fiscalDateEnding', 'totalRevenue']].iloc[3][1])
    cogs_3 = float(df_income_statement[['fiscalDateEnding', 'costOfRevenue']].iloc[3][1]) * -1
    gross_prof_3 = float(df_income_statement[['fiscalDateEnding', 'grossProfit']].iloc[3][1])
    rd_3 = float(df_income_statement[['fiscalDateEnding', 'researchAndDevelopment']].iloc[3][1]) * -1
    ga_3 = float(df_income_statement[['fiscalDateEnding', 'sellingGeneralAdministrative']].iloc[3][1]) * -1
    opex_3 = float(df_income_statement[['fiscalDateEnding', 'totalOperatingExpense']].iloc[3][1]) * -1
    ebit_3 = float(df_income_statement[['fiscalDateEnding', 'operatingIncome']].iloc[3][1]) 
    other_inc_3 = float(df_income_statement[['fiscalDateEnding', 'otherNonOperatingIncome']].iloc[3][1]) 
    ebt_3 = float(df_income_statement[['fiscalDateEnding', 'incomeBeforeTax']].iloc[3][1]) 
    inc_tax_3 = float(df_income_statement[['fiscalDateEnding', 'taxProvision']].iloc[3][1]) * -1
    net_inc_3 = float(df_income_statement[['fiscalDateEnding', 'netIncome']].iloc[3][1])

    rev_4 = float(df_income_statement[['fiscalDateEnding', 'totalRevenue']].iloc[4][1])
    cogs_4 = float(df_income_statement[['fiscalDateEnding', 'costOfRevenue']].iloc[4][1]) * -1
    gross_prof_4 = float(df_income_statement[['fiscalDateEnding', 'grossProfit']].iloc[4][1])
    rd_4 = float(df_income_statement[['fiscalDateEnding', 'researchAndDevelopment']].iloc[4][1]) * -1
    ga_4 = float(df_income_statement[['fiscalDateEnding', 'sellingGeneralAdministrative']].iloc[4][1]) * -1
    opex_4 = float(df_income_statement[['fiscalDateEnding', 'totalOperatingExpense']].iloc[4][1]) * -1
    ebit_4 = float(df_income_statement[['fiscalDateEnding', 'operatingIncome']].iloc[4][1]) 
    other_inc_4 = float(df_income_statement[['fiscalDateEnding', 'otherNonOperatingIncome']].iloc[4][1]) 
    ebt_4 = float(df_income_statement[['fiscalDateEnding', 'incomeBeforeTax']].iloc[4][1]) 
    inc_tax_4 = float(df_income_statement[['fiscalDateEnding', 'taxProvision']].iloc[4][1]) * -1
    net_inc_4 = float(df_income_statement[['fiscalDateEnding', 'netIncome']].iloc[4][1])  


    date0 = df_income_statement['fiscalDateEnding'].iloc[0]
    date1 = df_income_statement['fiscalDateEnding'].iloc[1]
    date2 = df_income_statement['fiscalDateEnding'].iloc[2]
    date3 = df_income_statement['fiscalDateEnding'].iloc[3]
    date4 = df_income_statement['fiscalDateEnding'].iloc[4]


    income_chart1 = go.Figure(go.Waterfall(
        name = "20", orientation = "v",
        measure = ["relative", "relative", "total", "relative", "relative", "total", "total", "relative", 'total', 'relative', 'total'],
        x = ["Revenue", "COGS", "Gross Profit", "R&D", "G&A", "Opex", "EBIT", "Other Income/Expense", "EBT", "Income Tax Exp", "Net Income"],
        textposition = "outside",
        text = [rev_0/1000, cogs_0/1000, gross_prof_0/1000, rd_0/1000, ga_0/1000, opex_0/1000, ebit_0/1000, other_inc_0/1000, ebt_0/1000, inc_tax_0/1000, net_inc_0/1000],
        y = [rev_0, cogs_0, gross_prof_0,rd_0, ga_0, opex_0, ebit_0, other_inc_0, ebt_0, inc_tax_0, net_inc_0],
        connector = {"line":{"color":"rgb(63, 63, 63)"}},
    ))

    income_chart1.update_layout(
            title = f"Profit and loss statement for {symbol} for FY ending {date0}",
            showlegend = True
    )


    income_chart2 = go.Figure(go.Waterfall(
        name = "20", orientation = "v",
        measure = ["relative", "relative", "total", "relative", "relative", "total", "total", "relative", 'total', 'relative', 'total'],
        x = ["Revenue", "COGS", "Gross Profit", "R&D", "G&A", "Opex", "EBIT", "Other Income/Expense", "EBT", "Income Tax Exp", "Net Income"],
        textposition = "outside",
        text = [rev_1/1000, cogs_1/1000, gross_prof_1/1000, rd_1/1000, ga_1/1000, opex_1/1000, ebit_1/1000, other_inc_1/1000, ebt_1/1000, inc_tax_1/1000, net_inc_1/1000],
        y = [rev_1, cogs_1, gross_prof_1, rd_1, ga_1, opex_1, ebit_1, other_inc_1, ebt_1, inc_tax_1, net_inc_1],
        connector = {"line":{"color":"rgb(63, 63, 63)"}},
    ))

    income_chart2.update_layout(
            title = f"Profit and loss statement for {symbol} for FY ending {date1}",
            showlegend = True
    )

    income_chart3 = go.Figure(go.Waterfall(
        name = "20", orientation = "v",
        measure = ["relative", "relative", "total", "relative", "relative", "total", "total", "relative", 'total', 'relative', 'total'],
        x = ["Revenue", "COGS", "Gross Profit", "R&D", "G&A", "Opex", "EBIT", "Other Income/Expense", "EBT", "Income Tax Exp", "Net Income"],
        textposition = "outside",
        text = [rev_2/1000, cogs_2/1000, gross_prof_2/1000, rd_2/1000, ga_2/1000, opex_2/1000, ebit_2/1000, other_inc_2/1000, ebt_2/1000, inc_tax_2/1000, net_inc_2/1000],
        y = [rev_2, cogs_2, gross_prof_2, rd_2, ga_2, opex_2, ebit_2, other_inc_2, ebt_2, inc_tax_2, net_inc_2],
        connector = {"line":{"color":"rgb(63, 63, 63)"}},
    ))

    income_chart3.update_layout(
            title = f"Profit and loss statement for {symbol} for FY ending {date2}",
            showlegend = True
    )

    income_chart4 = go.Figure(go.Waterfall(
        name = "20", orientation = "v",
        measure = ["relative", "relative", "total", "relative", "relative", "total", "total", "relative", 'total', 'relative', 'total'],
        x = ["Revenue", "COGS", "Gross Profit", "R&D", "G&A", "Opex", "EBIT", "Other Income/Expense", "EBT", "Income Tax Exp", "Net Income"],
        textposition = "outside",
        text = [rev_3/1000, cogs_3/1000, gross_prof_3/1000, rd_3/1000, ga_3/1000, opex_3/1000, ebit_3/1000, other_inc_3/1000, ebt_3/1000, inc_tax_3/1000, net_inc_3/1000],
        y = [rev_3, cogs_3, gross_prof_3, rd_3, ga_3, opex_3, ebit_3, other_inc_3, ebt_3, inc_tax_3, net_inc_3],
        connector = {"line":{"color":"rgb(63, 63, 63)"}},
    ))

    income_chart4.update_layout(
            title = f"Profit and loss statement for {symbol} for FY ending {date3}",
            showlegend = True
    )

    income_chart5 = go.Figure(go.Waterfall(
        name = "20", orientation = "v",
        measure = ["relative", "relative", "total", "relative", "relative", "total", "total", "relative", 'total', 'relative', 'total'],
        x = ["Revenue", "COGS", "Gross Profit", "R&D", "G&A", "Opex", "EBIT", "Other Income/Expense", "EBT", "Income Tax Exp", "Net Income"],
        textposition = "outside",
        text = [rev_4/1000, cogs_4/1000, gross_prof_4/1000, rd_4/1000, ga_4/1000, opex_4/1000, ebit_4/1000, other_inc_4/1000, ebt_4/1000, inc_tax_4/1000, net_inc_4/1000],
        y = [rev_4, cogs_4, gross_prof_4, rd_4, ga_4, opex_4, ebit_4, other_inc_4, ebt_4, inc_tax_4, net_inc_4],
        connector = {"line":{"color":"rgb(63, 63, 63)"}},
    ))

    income_chart5.update_layout(
            title = f"Profit and loss statement for {symbol} for FY ending {date4}",
            showlegend = True
    )

    #income_chart1
    #income_chart2
    #income_chart3
    #income_chart4
    #income_chart5
    
    return income_chart1.show(), income_chart2.show(), income_chart3.show(), income_chart4.show(), income_chart5.show()
